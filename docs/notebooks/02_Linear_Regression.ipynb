# %% [markdown]
# # Linear Regression

# %% [markdown]
# In this notebook

# %%
import cola
import numpy as np

Phi = np.random.randn(100, 10)
y = np.random.randn(100)

# %%
beta = cola.pinv(cola.lazify(Phi))@y
# Out:
# (10, 10)
# (10, 10)
